# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install pandas==2.2.3
# !pip install tensorflow==2.17.1
# !pip install pillow==11.1.0
# !pip install matplotlib==3.9.2
# !pip install transformers==4.38.2
# !pip install torch
# Out:
# Requirement already satisfied: pandas==2.2.3 in c:\users\pan12\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pan12\anaconda3\lib\site-packages (from pandas==2.2.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pan12\anaconda3\lib\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pan12\anaconda3\lib\site-packages (from pandas==2.2.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pan12\anaconda3\lib\site-packages (from pandas==2.2.3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pan12\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.16.0)
# Requirement already satisfied: tensorflow==2.17.1 in c:\users\pan12\anaconda3\lib\site-packages (2.17.1)
# Requirement already satisfied: tensorflow-intel==2.17.1 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow==2.17.1) (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.4.0)
# Requirement already satisfied: packaging in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.76.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.12.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pan12\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pan12\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pan12\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pan12\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pan12\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pan12\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pan12\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pan12\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.44.0)
# Requirement already satisfied: rich in c:\users\pan12\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (13.7.1)
# Requirement already satisfied: namex in c:\users\pan12\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.1.0)
# Requirement already satisfied: optree in c:\users\pan12\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pan12\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pan12\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pan12\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pan12\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.1.0)
# Requirement already satisfied: pillow==11.1.0 in c:\users\pan12\anaconda3\lib\site-packages (11.1.0)
# Requirement already satisfied: matplotlib==3.9.2 in c:\users\pan12\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pan12\anaconda3\lib\site-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pan12\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.16.0)
# Requirement already satisfied: transformers==4.38.2 in c:\users\pan12\anaconda3\lib\site-packages (4.38.2)
# Requirement already satisfied: filelock in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (2024.9.11)
# Requirement already satisfied: requests in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\pan12\anaconda3\lib\site-packages (from transformers==4.38.2) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pan12\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pan12\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (4.15.0)
# Requirement already satisfied: colorama in c:\users\pan12\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.38.2) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pan12\anaconda3\lib\site-packages (from requests->transformers==4.38.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pan12\anaconda3\lib\site-packages (from requests->transformers==4.38.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pan12\anaconda3\lib\site-packages (from requests->transformers==4.38.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pan12\anaconda3\lib\site-packages (from requests->transformers==4.38.2) (2025.4.26)
# Requirement already satisfied: torch in c:\users\pan12\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: filelock in c:\users\pan12\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\pan12\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pan12\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pan12\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\pan12\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\pan12\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\pan12\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pan12\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pan12\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import zipfile
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten
from keras.applications import VGG16
from keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing import image
import random

# %%
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
batch_size = 32
n_epochs = 5
img_rows, img_cols = 224, 224
input_shape = (224, 224, 3)

# %%
import tarfile
import urllib.request
import os
import shutil

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/ZjXM4RKxlBK9__ZjHBLl5A/aircraft-damage-dataset-v1.tar"
tar_filename = "aircraft_damage_dataset_v1.tar"
extracted_folder = "aircraft_damage_dataset_v1"
urllib.request.urlretrieve(url, tar_filename)
print(f"Downloaded {tar_filename}. Extraction will begin now.")

# Check if the folder already exists
if os.path.exists(extracted_folder):
    print(f"The folder '{extracted_folder}' already exists. Removing the existing folder.")

    # Remove the existing folder to avoid overwriting or duplication
    shutil.rmtree(extracted_folder)
    print(f"Removed the existing folder: {extracted_folder}")

# Extract the contents of the tar file
with tarfile.open(tar_filename, "r") as tar_ref:
    tar_ref.extractall()  # This will extract to the current directory
    print(f"Extracted {tar_filename} successfully.")
# Out:
# Downloaded aircraft_damage_dataset_v1.tar. Extraction will begin now.
# Extracted aircraft_damage_dataset_v1.tar successfully.

# %%
extract_path = "aircraft_damage_dataset_v1"
train_dir = os.path.join(extract_path, 'train')
test_dir = os.path.join(extract_path, 'test')
valid_dir = os.path.join(extract_path, 'valid')

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_rows, img_cols),   # Resize images to the size VGG16 expects
    batch_size=batch_size,
    seed = seed_value,
    class_mode='binary',
    shuffle=True # Binary classification: dent vs crack
)
# Out:
# Found 300 images belonging to 2 classes.

# %%
valid_generator = valid_datagen.flow_from_directory(
    directory=valid_dir,
    class_mode='binary',
    seed=seed_value,
    batch_size=batch_size,
    shuffle=False,
    target_size=(img_rows, img_cols)

)
# Out:
# Found 96 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    directory=test_dir,
    class_mode='binary',
    seed=seed_value,
    batch_size=batch_size,
    shuffle=False,
    target_size=(img_rows, img_cols)
)
# Out:
# Found 50 images belonging to 2 classes.

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_rows, img_cols, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 21s 0us/step

# %%
output = base_model.layers[-1].output
output = keras.layers.Flatten()(output)
base_model = Model(base_model.input, output)

for layer in base_model.layers:
    layer.trainable = False

# %%
model = Sequential()
model.add(base_model)
model.add(Dense(512, activation='relu',))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    epochs=n_epochs,
    validation_data=valid_generator,
)
# Out:
# Epoch 1/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 46s 4s/step - accuracy: 0.5367 - loss: 0.7201 - val_accuracy: 0.6042 - val_loss: 0.6338
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7233 - loss: 0.5535 - val_accuracy: 0.6979 - val_loss: 0.5821
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.7767 - loss: 0.4737 - val_accuracy: 0.7188 - val_loss: 0.5486
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.8133 - loss: 0.4123 - val_accuracy: 0.6562 - val_loss: 0.6457
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.8800 - loss: 0.3204 - val_accuracy: 0.7083 - val_loss: 0.5098

# %%
train_history = model.history.history

# %%
plt.title("Training Loss")
plt.ylabel("Loss")
plt.xlabel('Epoch')
plt.plot(train_history['loss'])
plt.show()

plt.title("Validation Loss")
plt.ylabel("Loss")
plt.xlabel('Epoch')
plt.plot(train_history['val_loss'])
plt.show()

# %%
figsize=(5, 5)
plt.plot(train_history['accuracy'], label='Training Accuracy')
plt.plot(train_history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6875 - loss: 0.7326
# Test Loss: 0.7326
# Test Accuracy: 0.6875

# %%
def plot_image_with_title(image, model, true_label, predicted_label, class_names):
    plt.figure(figsize=(6, 6))
    plt.imshow(image)

    # Convert labels from one-hot to class indices if needed, but for binary labels it's just 0 or 1
    true_label_name = class_names[true_label]  # Labels are already in class indices
    pred_label_name = class_names[predicted_label]  # Predictions are 0 or 1

    plt.title(f"True: {true_label_name}\nPred: {pred_label_name}")
    plt.axis('off')
    plt.show()

# Function to test the model with images from the test set
def test_model_on_image(test_generator, model, index_to_plot=0):
    # Get a batch of images and labels from the test generator
    test_images, test_labels = next(test_generator)

    # Make predictions on the batch
    predictions = model.predict(test_images)

    # In binary classification, predictions are probabilities (float). Convert to binary (0 or 1)
    predicted_classes = (predictions > 0.5).astype(int).flatten()

    # Get the class indices from the test generator and invert them to get class names
    class_indices = test_generator.class_indices
    class_names = {v: k for k, v in class_indices.items()}  # Invert the dictionary

    # Specify the image to display based on the index
    image_to_plot = test_images[index_to_plot]
    true_label = test_labels[index_to_plot]
    predicted_label = predicted_classes[index_to_plot]

    # Plot the selected image with its true and predicted labels
    plot_image_with_title(image=image_to_plot, model=model, true_label=true_label, predicted_label=predicted_label, class_names=class_names)

# %%
test_model_on_image(test_generator,model, index_to_plot=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
import torch
import tensorflow as tf
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

# %%
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
# Out:
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]

# %%
class BlipCaptionSummaryLayer(tf.keras.layers.Layer):
    def __init__(self, processor, model, **kwargs):

        super().__init__(**kwargs)
        self.processor = processor
        self.model = model
    def call(self, image_path, task):
        return tf.py_function(self.process_image, [image_path, task], tf.string)
    def process_image(self, image_path, task):
         try:
            # Decode the image path from the TensorFlow tensor to a Python string
            image_path_str = image_path.numpy().decode("utf-8")

            # Open the image using PIL and convert it to RGB format
            image = Image.open(image_path_str).convert("RGB")

            # Set the appropriate prompt based on the task
            if task.numpy().decode("utf-8") == "caption":
                prompt = "This is a picture of"  # Modify prompt for more natural output
            else:
                prompt = "This is a detailed photo showing"  # Modify for summary

            # Prepare inputs for the BLIP model
            inputs = self.processor(images=image, text=prompt, return_tensors="pt")

            # Generate text output using the BLIP model
            output = self.model.generate(**inputs)

            # Decode the output into a readable string
            result = self.processor.decode(output[0], skip_special_tokens=True)
            return result
         except Exception as e:
            print(f"Error: {e}")
            return "Error processing image"

# %%
def generate_text(image_path, task):
    blip_layer = BlipCaptionSummaryLayer(processor,model)

    return blip_layer(image_path, task)

# %%
image_path = tf.constant("aircraft_damage_dataset_v1/test/dent/144_10_JPG_jpg.rf.4d008cc33e217c1606b76585469d626b.jpg")  # actual path of image

# Generate a caption for the image
caption = generate_text(image_path, tf.constant("caption"))
# Decode and print the generated caption
print("Caption:", caption.numpy().decode("utf-8"))

# Generate a summary for the image
summary = generate_text(image_path, tf.constant("summary"))
# Decode and print the generated summary
print("Summary:", summary.numpy().decode("utf-8"))
# Out:
# Caption: this is a picture of a plane
# Summary: this is a detailed photo showing the engine of a boeing 747

# %%
image_url = "aircraft_damage_dataset_v1/test/dent/149_22_JPG_jpg.rf.4899cbb6f4aad9588fa3811bb886c34d.jpg"
img=plt.imread(image_url)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = tf.constant("aircraft_damage_dataset_v1/test/dent/149_22_JPG_jpg.rf.4899cbb6f4aad9588fa3811bb886c34d.jpg")
caption = generate_text(image_path, tf.constant("caption"))
print("Caption:", caption.numpy().decode("utf-8"))
summary = generate_text(image_path, tf.constant("summary"))
print("Summary:", summary.numpy().decode("utf-8"))
# Out:
# Caption: this is a picture of a plane that was sitting on the ground in a field
# Summary: this is a detailed photo showing the damage to the fuselage of the aircraft
